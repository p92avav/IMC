# %% [markdown]
# **University of Córdoba**
#
# **Computer Engineering**
# **Computer Science Engineering Degree**
# **4th Course**
#
# **Introduction to Computational Models**
#
# **Lab Assignment 4: Support Vector Machines**
#
# **Valentín Gabriel Avram Aenachioei**
# **( p92avavv@uco.es )**
#
# **DNI: 03524931C**

# %% [markdown]
# **Introduction**
#
# In this Notebook we will realize the 4th practical assignment of the subject, the Support Vector Machine. We will focus on answering the given questions, using the given script (libsvm.py), modifying it as needed.
